# %% [markdown]
# # Testing the Video Intelligence API

# %%
# from google.cloud import 
import os
import io
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'my_key.json'
from google.cloud import videointelligence

# %% [markdown]
# ## Object tracking - process the video with Video Intelligence API From the local pc

# %%
video_client = videointelligence.VideoIntelligenceServiceClient()
features = [videointelligence.Feature.OBJECT_TRACKING]
path = "/Users/eliordana/Desktop/cloud_func/video.mp4"
with io.open(path, "rb") as file:
    input_content = file.read()

operation = video_client.annotate_video(
    request={"features": features, "input_content": input_content}
)
print("\nProcessing video for object annotations.")

result = operation.result(timeout=500)
print("\nFinished processing.\n")

# The first result is retrieved because a single video was processed.
object_annotations = result.annotation_results[0].object_annotations
# Out:
# Processing video for object annotations.
#
# Finished processing.

# %%
# Get only the first annotation for demo purposes.
object_annotation = object_annotations[0]
print("Entity description: {}".format(object_annotation.entity.description))
if object_annotation.entity.entity_id:
    print("Entity id: {}".format(object_annotation.entity.entity_id))

print(
    "Segment: {}s to {}s".format(
        object_annotation.segment.start_time_offset.seconds
        + object_annotation.segment.start_time_offset.microseconds / 1e6,
        object_annotation.segment.end_time_offset.seconds
        + object_annotation.segment.end_time_offset.microseconds / 1e6,
    )
)

print("Confidence: {}".format(object_annotation.confidence))

# Here we print only the bounding box of the first frame in this segment
frame = object_annotation.frames[0]
box = frame.normalized_bounding_box
print(
    "Time offset of the first frame: {}s".format(
        frame.time_offset.seconds + frame.time_offset.microseconds / 1e6
    )
)
print("Bounding box position:")
print("\tleft  : {}".format(box.left))
print("\ttop   : {}".format(box.top))
print("\tright : {}".format(box.right))
print("\tbottom: {}".format(box.bottom))
print("\n")
# Out:
# Entity description: sunglasses
# Entity id: /m/017ftj
# Segment: 1.626625s to 1.626625s
# Confidence: 0.8484508991241455
# Time offset of the first frame: 1.626625s
# Bounding box position:
# 	left  : 0.36135154962539673
# 	top   : 0.005173176527023315
# 	right : 0.5663079023361206
# 	bottom: 0.12535697221755981

# %%
result.annotation_results[0].object_annotations
# Out:
# [segment {
#   start_time_offset {
#     seconds: 1
#     nanos: 626625000
#   }
#   end_time_offset {
#     seconds: 1
#     nanos: 626625000
#   }
# }
# entity {
#   entity_id: "/m/017ftj"
#   description: "sunglasses"
#   language_code: "en-US"
# }
# confidence: 0.848450899
# frames {
#   normalized_bounding_box {
#     left: 0.36135155
#     top: 0.00517317653
#     right: 0.566307902
#     bottom: 0.125356972
#   }
#   time_offset {
#     seconds: 1
#     nanos: 626625000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 1
#     nanos: 626625000
#   }
#   end_time_offset {
#     seconds: 2
#     nanos: 627625000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.863209546
# frames {
#   normalized_bounding_box {
#     left: 0.140445322
#     top: 0.00588282943
#     right: 0.823633194
#     bottom: 0.998149514
#   }
#   time_offset {
#     seconds: 1
#     nanos: 626625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.134608969
#     top: 0.0162264556
#     right: 0.797507942
#     bottom: 0.995275438
#   }
#   time_offset {
#     seconds: 1
#     nanos: 751750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.124877229
#     top: 0.0191366989
#     right: 0.784017861
#     bottom: 0.991641
#   }
#   time_offset {
#     seconds: 1
#     nanos: 876875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.103165157
#     top: 0.0193264466
#     right: 0.770586371
#     bottom: 0.991663694
#   }
#   time_offset {
#     seconds: 2
#     nanos: 2000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0937755257
#     top: 0.0139192
#     right: 0.785643816
#     bottom: 0.996995509
#   }
#   time_offset {
#     seconds: 2
#     nanos: 127125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.111395285
#     top: 0.0217404924
#     right: 0.838655889
#     bottom: 0.990163684
#   }
#   time_offset {
#     seconds: 2
#     nanos: 252250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.148166344
#     top: 0.0118538179
#     right: 0.869653165
#     bottom: 0.995597243
#   }
#   time_offset {
#     seconds: 2
#     nanos: 377375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.171566844
#     top: 0.00878784899
#     right: 0.899336159
#     bottom: 0.99124527
#   }
#   time_offset {
#     seconds: 2
#     nanos: 502500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.284279615
#     top: 0.140829608
#     right: 0.725742161
#     bottom: 0.958378673
#   }
#   time_offset {
#     seconds: 2
#     nanos: 627625000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 1
#     nanos: 626625000
#   }
#   end_time_offset {
#     seconds: 2
#     nanos: 377375000
#   }
# }
# entity {
#   entity_id: "/m/09j2d"
#   description: "clothing"
#   language_code: "en-US"
# }
# confidence: 0.682065725
# frames {
#   normalized_bounding_box {
#     left: 0.158276588
#     top: 0.385166675
#     right: 0.795564055
#     bottom: 0.989510417
#   }
#   time_offset {
#     seconds: 1
#     nanos: 626625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.15641883
#     top: 0.285884827
#     right: 0.787424922
#     bottom: 0.982775092
#   }
#   time_offset {
#     seconds: 1
#     nanos: 751750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.143760398
#     top: 0.244035959
#     right: 0.77167064
#     bottom: 0.971704721
#   }
#   time_offset {
#     seconds: 1
#     nanos: 876875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.125389487
#     top: 0.272795916
#     right: 0.74620986
#     bottom: 0.97786
#   }
#   time_offset {
#     seconds: 2
#     nanos: 2000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.115284972
#     top: 0.356242448
#     right: 0.764405
#     bottom: 0.982788086
#   }
#   time_offset {
#     seconds: 2
#     nanos: 127125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.126699701
#     top: 0.487482607
#     right: 0.824677646
#     bottom: 0.977175713
#   }
#   time_offset {
#     seconds: 2
#     nanos: 252250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.136921
#     top: 0.568308234
#     right: 0.880784869
#     bottom: 0.991621494
#   }
#   time_offset {
#     seconds: 2
#     nanos: 377375000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 1
#     nanos: 751750000
#   }
#   end_time_offset {
#     seconds: 1
#     nanos: 751750000
#   }
# }
# entity {
#   entity_id: "/m/0zvk5"
#   description: "helmet"
#   language_code: "en-US"
# }
# confidence: 0.643737614
# frames {
#   normalized_bounding_box {
#     left: 0.353521645
#     top: 0.00182311237
#     right: 0.590067446
#     bottom: 0.379038036
#   }
#   time_offset {
#     seconds: 1
#     nanos: 751750000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 2
#     nanos: 252250000
#   }
#   end_time_offset {
#     seconds: 2
#     nanos: 627625000
#   }
# }
# entity {
#   entity_id: "/m/017ftj"
#   description: "sunglasses"
#   language_code: "en-US"
# }
# confidence: 0.904043674
# frames {
#   normalized_bounding_box {
#     left: 0.332950175
#     top: 0.0950397253
#     right: 0.560391068
#     bottom: 0.256073236
#   }
#   time_offset {
#     seconds: 2
#     nanos: 252250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.321807235
#     top: 0.200768724
#     right: 0.565053821
#     bottom: 0.358486205
#   }
#   time_offset {
#     seconds: 2
#     nanos: 377375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.280692101
#     top: 0.233644173
#     right: 0.545303702
#     bottom: 0.403176308
#   }
#   time_offset {
#     seconds: 2
#     nanos: 502500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.259552509
#     top: 0.282469749
#     right: 0.549522817
#     bottom: 0.495672524
#   }
#   time_offset {
#     seconds: 2
#     nanos: 627625000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 2
#     nanos: 752750000
#   }
#   end_time_offset {
#     seconds: 3
#     nanos: 3000000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.827024519
# frames {
#   normalized_bounding_box {
#     left: 0.315506458
#     top: 0.312689424
#     right: 0.440851331
#     bottom: 0.722839475
#   }
#   time_offset {
#     seconds: 2
#     nanos: 752750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.320825517
#     top: 0.277830929
#     right: 0.452586293
#     bottom: 0.708354533
#   }
#   time_offset {
#     seconds: 2
#     nanos: 877875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0454400182
#     top: 0.0218204651
#     right: 0.237319529
#     bottom: 0.758950472
#   }
#   time_offset {
#     seconds: 3
#     nanos: 3000000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 2
#     nanos: 752750000
#   }
#   end_time_offset {
#     seconds: 4
#     nanos: 379375000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.85152775
# frames {
#   normalized_bounding_box {
#     left: 0.0532770306
#     top: 0.357483
#     right: 0.370105624
#     bottom: 1
#   }
#   time_offset {
#     seconds: 2
#     nanos: 752750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.108997539
#     top: 0.383043647
#     right: 0.362868667
#     bottom: 0.987303734
#   }
#   time_offset {
#     seconds: 2
#     nanos: 877875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0463416427
#     top: 0.421027929
#     right: 0.359787464
#     bottom: 0.997114062
#   }
#   time_offset {
#     seconds: 3
#     nanos: 3000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.05563768
#     top: 0.418096036
#     right: 0.36868754
#     bottom: 1.00352216
#   }
#   time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0325871781
#     top: 0.371722877
#     right: 0.345610023
#     bottom: 0.959509432
#   }
#   time_offset {
#     seconds: 3
#     nanos: 253250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.000192487336
#     top: 0.109720729
#     right: 0.366946816
#     bottom: 1.00514317
#   }
#   time_offset {
#     seconds: 3
#     nanos: 378375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0147573072
#     top: 0.08012411
#     right: 0.365055948
#     bottom: 0.936113715
#   }
#   time_offset {
#     seconds: 3
#     nanos: 503500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0666999668
#     top: -0.0369801968
#     right: 0.41576308
#     bottom: 0.816048563
#   }
#   time_offset {
#     seconds: 3
#     nanos: 628625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.157677919
#     top: 0.0767595842
#     right: 0.460634232
#     bottom: 0.644969106
#   }
#   time_offset {
#     seconds: 3
#     nanos: 753750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.161571592
#     top: 0.0743284449
#     right: 0.450947344
#     bottom: 0.617530942
#   }
#   time_offset {
#     seconds: 3
#     nanos: 878875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.169297338
#     top: 0.0681854934
#     right: 0.457896829
#     bottom: 0.609958708
#   }
#   time_offset {
#     seconds: 4
#     nanos: 4000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.155978784
#     top: 0.011416018
#     right: 0.571784317
#     bottom: 0.632505
#   }
#   time_offset {
#     seconds: 4
#     nanos: 129125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.17793344
#     top: -0.00252781576
#     right: 0.60227561
#     bottom: 0.623911679
#   }
#   time_offset {
#     seconds: 4
#     nanos: 254250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.1864952
#     top: -0.00738958875
#     right: 0.611449599
#     bottom: 0.619433641
#   }
#   time_offset {
#     seconds: 4
#     nanos: 379375000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 2
#     nanos: 752750000
#   }
#   end_time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
# }
# entity {
#   entity_id: "/m/09j2d"
#   description: "clothing"
#   language_code: "en-US"
# }
# confidence: 0.590411365
# frames {
#   normalized_bounding_box {
#     left: 0.0203509927
#     top: 0.739132702
#     right: 0.375795275
#     bottom: 0.996074677
#   }
#   time_offset {
#     seconds: 2
#     nanos: 752750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0322737098
#     top: 0.73796469
#     right: 0.387482405
#     bottom: 0.994446874
#   }
#   time_offset {
#     seconds: 2
#     nanos: 877875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0365774632
#     top: 0.747648776
#     right: 0.340264827
#     bottom: 0.994413674
#   }
#   time_offset {
#     seconds: 3
#     nanos: 3000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0909998938
#     top: 0.738457859
#     right: 0.317858
#     bottom: 0.979157329
#   }
#   time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 3
#     nanos: 3000000
#   }
#   end_time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
# }
# entity {
#   entity_id: "/m/09j2d"
#   description: "clothing"
#   language_code: "en-US"
# }
# confidence: 0.588321567
# frames {
#   normalized_bounding_box {
#     left: 0.0615600273
#     top: 0.0627763569
#     right: 0.225455493
#     bottom: 0.607750535
#   }
#   time_offset {
#     seconds: 3
#     nanos: 3000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0603324287
#     top: 0.107447967
#     right: 0.234235838
#     bottom: 0.60106653
#   }
#   time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
#   end_time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
# }
# entity {
#   entity_id: "/m/09j2d"
#   description: "clothing"
#   language_code: "en-US"
# }
# confidence: 0.60604471
# frames {
#   normalized_bounding_box {
#     left: 0.644694
#     top: 0.142653689
#     right: 0.766896
#     bottom: 0.317607582
#   }
#   time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
#   end_time_offset {
#     seconds: 3
#     nanos: 503500000
#   }
# }
# entity {
#   entity_id: "/m/09j2d"
#   description: "clothing"
#   language_code: "en-US"
# }
# confidence: 0.599437594
# frames {
#   normalized_bounding_box {
#     left: 0.70666194
#     top: 0.00446860492
#     right: 0.876547098
#     bottom: 0.379950106
#   }
#   time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.331480622
#     top: 0.280680478
#     right: 0.866348445
#     bottom: 0.981154263
#   }
#   time_offset {
#     seconds: 3
#     nanos: 253250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.324212223
#     top: 0.23188664
#     right: 0.837952852
#     bottom: 0.954994917
#   }
#   time_offset {
#     seconds: 3
#     nanos: 378375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.301829278
#     top: 0.251642615
#     right: 0.71656847
#     bottom: 0.882436872
#   }
#   time_offset {
#     seconds: 3
#     nanos: 503500000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
#   end_time_offset {
#     seconds: 3
#     nanos: 378375000
#   }
# }
# entity {
#   entity_id: "/m/09j2d"
#   description: "clothing"
#   language_code: "en-US"
# }
# confidence: 0.548644543
# frames {
#   normalized_bounding_box {
#     left: 0.219137728
#     right: 0.412337244
#     bottom: 0.344443083
#   }
#   time_offset {
#     seconds: 3
#     nanos: 128125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.00887076
#     top: 0.478589356
#     right: 0.337761
#     bottom: 0.991054714
#   }
#   time_offset {
#     seconds: 3
#     nanos: 253250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.00308436085
#     top: 0.59185195
#     right: 0.289794058
#     bottom: 0.973135352
#   }
#   time_offset {
#     seconds: 3
#     nanos: 378375000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 3
#     nanos: 378375000
#   }
#   end_time_offset {
#     seconds: 3
#     nanos: 753750000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.860923886
# frames {
#   normalized_bounding_box {
#     left: 0.178610489
#     top: 0.0425413139
#     right: 0.899797559
#     bottom: 0.942756
#   }
#   time_offset {
#     seconds: 3
#     nanos: 378375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.164083272
#     top: 0.0388930365
#     right: 0.85059607
#     bottom: 0.89636749
#   }
#   time_offset {
#     seconds: 3
#     nanos: 503500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.305450857
#     top: -0.00175071484
#     right: 0.991912901
#     bottom: 0.747839808
#   }
#   time_offset {
#     seconds: 3
#     nanos: 628625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.453221887
#     top: -0.00703294063
#     right: 0.875317037
#     bottom: 0.660433829
#   }
#   time_offset {
#     seconds: 3
#     nanos: 753750000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 3
#     nanos: 628625000
#   }
#   end_time_offset {
#     seconds: 3
#     nanos: 628625000
#   }
# }
# entity {
#   entity_id: "/m/01r546"
#   description: "earrings"
#   language_code: "en-US"
# }
# confidence: 0.608459771
# frames {
#   normalized_bounding_box {
#     left: 0.399266154
#     top: 0.458139211
#     right: 0.460595101
#     bottom: 0.719088554
#   }
#   time_offset {
#     seconds: 3
#     nanos: 628625000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 3
#     nanos: 628625000
#   }
#   end_time_offset {
#     seconds: 3
#     nanos: 628625000
#   }
# }
# entity {
#   entity_id: "/m/01r546"
#   description: "earrings"
#   language_code: "en-US"
# }
# confidence: 0.548949
# frames {
#   normalized_bounding_box {
#     left: 0.188419864
#     top: 0.396747589
#     right: 0.255461812
#     bottom: 0.715723276
#   }
#   time_offset {
#     seconds: 3
#     nanos: 628625000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 3
#     nanos: 628625000
#   }
#   end_time_offset {
#     seconds: 4
#     nanos: 754750000
#   }
# }
# entity {
#   entity_id: "/m/029zz6"
#   description: "display device"
#   language_code: "en-US"
# }
# confidence: 0.612864733
# frames {
#   normalized_bounding_box {
#     left: 0.10066542
#     top: 0.00157240033
#     right: 0.903033257
#     bottom: 0.99698174
#   }
#   time_offset {
#     seconds: 3
#     nanos: 628625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.10066542
#     top: 0.00157240033
#     right: 0.903033257
#     bottom: 0.99698174
#   }
#   time_offset {
#     seconds: 3
#     nanos: 753750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.10066542
#     top: 0.00157240033
#     right: 0.903033257
#     bottom: 0.99698174
#   }
#   time_offset {
#     seconds: 3
#     nanos: 878875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.10066542
#     top: 0.00157240033
#     right: 0.903033257
#     bottom: 0.99698174
#   }
#   time_offset {
#     seconds: 4
#     nanos: 4000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.10066542
#     top: 0.00157240033
#     right: 0.903033257
#     bottom: 0.99698174
#   }
#   time_offset {
#     seconds: 4
#     nanos: 129125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.13375929
#     top: 0.00295258
#     right: 0.869302511
#     bottom: 0.999997437
#   }
#   time_offset {
#     seconds: 4
#     nanos: 254250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.130894229
#     top: 0.00105452945
#     right: 0.866319597
#     bottom: 0.998264551
#   }
#   time_offset {
#     seconds: 4
#     nanos: 379375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.10918317
#     top: 0.00289460109
#     right: 0.873276949
#     bottom: 0.999344826
#   }
#   time_offset {
#     seconds: 4
#     nanos: 504500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.100291267
#     top: -0.0209270343
#     right: 0.864355922
#     bottom: 0.975379944
#   }
#   time_offset {
#     seconds: 4
#     nanos: 629625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.0112106064
#     top: -0.0104118967
#     right: 0.930836618
#     bottom: 0.979903877
#   }
#   time_offset {
#     seconds: 4
#     nanos: 754750000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 3
#     nanos: 753750000
#   }
#   end_time_offset {
#     seconds: 3
#     nanos: 753750000
#   }
# }
# entity {
#   entity_id: "/j/5qg9b8"
#   description: "packaged goods"
#   language_code: "en-US"
# }
# confidence: 0.558969676
# frames {
#   normalized_bounding_box {
#     left: 0.116718054
#     right: 0.887003899
#     bottom: 1
#   }
#   time_offset {
#     seconds: 3
#     nanos: 753750000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 3
#     nanos: 878875000
#   }
#   end_time_offset {
#     seconds: 4
#     nanos: 129125000
#   }
# }
# entity {
#   entity_id: "/m/06z37_"
#   description: "picture frame"
#   language_code: "en-US"
# }
# confidence: 0.603642344
# frames {
#   normalized_bounding_box {
#     left: 0.122774035
#     top: 0.00868696
#     right: 0.876518369
#     bottom: 1
#   }
#   time_offset {
#     seconds: 3
#     nanos: 878875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.122207925
#     top: 0.0120280888
#     right: 0.870994866
#     bottom: 1.00000012
#   }
#   time_offset {
#     seconds: 4
#     nanos: 4000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.131628811
#     top: 0.00407338794
#     right: 0.867797673
#     bottom: 0.999820709
#   }
#   time_offset {
#     seconds: 4
#     nanos: 129125000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 5
#     nanos: 130125000
#   }
#   end_time_offset {
#     seconds: 5
#     nanos: 130125000
#   }
# }
# entity {
#   entity_id: "/m/06z37_"
#   description: "picture frame"
#   language_code: "en-US"
# }
# confidence: 0.718506575
# frames {
#   normalized_bounding_box {
#     left: 0.931217611
#     top: 0.312295765
#     right: 0.999119818
#     bottom: 0.568317294
#   }
#   time_offset {
#     seconds: 5
#     nanos: 130125000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 5
#     nanos: 505500000
#   }
#   end_time_offset {
#     seconds: 5
#     nanos: 505500000
#   }
# }
# entity {
#   entity_id: "/m/01b7fy"
#   description: "headphones"
#   language_code: "en-US"
# }
# confidence: 0.827936
# frames {
#   normalized_bounding_box {
#     left: 0.425270975
#     top: 0.209385559
#     right: 0.585330307
#     bottom: 0.564223647
#   }
#   time_offset {
#     seconds: 5
#     nanos: 505500000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 6
#     nanos: 756750000
#   }
#   end_time_offset {
#     seconds: 6
#     nanos: 756750000
#   }
# }
# entity {
#   entity_id: "/m/09j2d"
#   description: "clothing"
#   language_code: "en-US"
# }
# confidence: 0.513678312
# frames {
#   normalized_bounding_box {
#     left: 0.446174622
#     top: 0.863960922
#     right: 0.598474503
#     bottom: 0.999358118
#   }
#   time_offset {
#     seconds: 6
#     nanos: 756750000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 6
#     nanos: 881875000
#   }
#   end_time_offset {
#     seconds: 9
#     nanos: 259250000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.938125908
# frames {
#   normalized_bounding_box {
#     left: 0.43344146
#     top: 0.387307674
#     right: 0.610507786
#     bottom: 0.882933259
#   }
#   time_offset {
#     seconds: 6
#     nanos: 881875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.422860861
#     top: 0.32976532
#     right: 0.599423826
#     bottom: 0.813470602
#   }
#   time_offset {
#     seconds: 7
#     nanos: 7000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.442283094
#     top: 0.30690214
#     right: 0.621005595
#     bottom: 0.777106166
#   }
#   time_offset {
#     seconds: 7
#     nanos: 132125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.447581053
#     top: 0.301224262
#     right: 0.626232147
#     bottom: 0.769858599
#   }
#   time_offset {
#     seconds: 7
#     nanos: 257250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.451598853
#     top: 0.301518083
#     right: 0.63024503
#     bottom: 0.770044625
#   }
#   time_offset {
#     seconds: 7
#     nanos: 382375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.456360877
#     top: 0.313863158
#     right: 0.607646942
#     bottom: 0.759442568
#   }
#   time_offset {
#     seconds: 7
#     nanos: 507500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.450935572
#     top: 0.315236032
#     right: 0.600052834
#     bottom: 0.758895278
#   }
#   time_offset {
#     seconds: 7
#     nanos: 632625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.448022872
#     top: 0.311390609
#     right: 0.596992195
#     bottom: 0.754918873
#   }
#   time_offset {
#     seconds: 7
#     nanos: 757750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.449972153
#     top: 0.263452381
#     right: 0.577581048
#     bottom: 0.774079919
#   }
#   time_offset {
#     seconds: 7
#     nanos: 882875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.447851688
#     top: 0.254168063
#     right: 0.573522091
#     bottom: 0.768682957
#   }
#   time_offset {
#     seconds: 8
#     nanos: 8000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.450378746
#     top: 0.252824336
#     right: 0.57591
#     bottom: 0.767618299
#   }
#   time_offset {
#     seconds: 8
#     nanos: 133125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.461143315
#     top: 0.310717165
#     right: 0.614598334
#     bottom: 0.788567066
#   }
#   time_offset {
#     seconds: 8
#     nanos: 258250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.470568568
#     top: 0.334742665
#     right: 0.625658035
#     bottom: 0.809935868
#   }
#   time_offset {
#     seconds: 8
#     nanos: 383375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.48100704
#     top: 0.353403896
#     right: 0.636096478
#     bottom: 0.828597069
#   }
#   time_offset {
#     seconds: 8
#     nanos: 508500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.491445512
#     top: 0.372065097
#     right: 0.646535
#     bottom: 0.847258329
#   }
#   time_offset {
#     seconds: 8
#     nanos: 633625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.501884
#     top: 0.390726328
#     right: 0.656973481
#     bottom: 0.86591953
#   }
#   time_offset {
#     seconds: 8
#     nanos: 758750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.512322485
#     top: 0.409387529
#     right: 0.667411923
#     bottom: 0.884580731
#   }
#   time_offset {
#     seconds: 8
#     nanos: 883875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.522760928
#     top: 0.42804876
#     right: 0.677850366
#     bottom: 0.903242
#   }
#   time_offset {
#     seconds: 9
#     nanos: 9000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.47221306
#     top: 0.33577475
#     right: 0.635131
#     bottom: 0.834538937
#   }
#   time_offset {
#     seconds: 9
#     nanos: 134125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.388537467
#     top: 0.179223135
#     right: 0.659767151
#     bottom: 0.976534486
#   }
#   time_offset {
#     seconds: 9
#     nanos: 259250000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 6
#     nanos: 881875000
#   }
#   end_time_offset {
#     seconds: 6
#     nanos: 881875000
#   }
# }
# entity {
#   entity_id: "/m/050k8"
#   description: "mobile phone"
#   language_code: "en-US"
# }
# confidence: 0.618746877
# frames {
#   normalized_bounding_box {
#     left: 0.363146961
#     top: 0.136226863
#     right: 0.651634276
#     bottom: 1
#   }
#   time_offset {
#     seconds: 6
#     nanos: 881875000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 7
#     nanos: 257250000
#   }
#   end_time_offset {
#     seconds: 7
#     nanos: 257250000
#   }
# }
# entity {
#   entity_id: "/m/0jbk"
#   description: "animal"
#   language_code: "en-US"
# }
# confidence: 0.683100343
# frames {
#   normalized_bounding_box {
#     left: 0.440051079
#     top: 0.28024292
#     right: 0.589060903
#     bottom: 0.744819283
#   }
#   time_offset {
#     seconds: 7
#     nanos: 257250000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 7
#     nanos: 382375000
#   }
#   end_time_offset {
#     seconds: 9
#     nanos: 259250000
#   }
# }
# entity {
#   entity_id: "/m/02pd37"
#   description: "overall"
#   language_code: "en-US"
# }
# confidence: 0.612558782
# frames {
#   normalized_bounding_box {
#     left: 0.436356694
#     top: 0.326062024
#     right: 0.591136813
#     bottom: 0.748175204
#   }
#   time_offset {
#     seconds: 7
#     nanos: 382375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.451398224
#     top: 0.534576237
#     right: 0.561347306
#     bottom: 0.743934155
#   }
#   time_offset {
#     seconds: 7
#     nanos: 507500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.447765321
#     top: 0.310581356
#     right: 0.58562
#     bottom: 0.753484726
#   }
#   time_offset {
#     seconds: 7
#     nanos: 632625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.462224543
#     top: 0.260111958
#     right: 0.579138041
#     bottom: 0.722421706
#   }
#   time_offset {
#     seconds: 7
#     nanos: 757750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.454556018
#     top: 0.283950031
#     right: 0.57496196
#     bottom: 0.733327687
#   }
#   time_offset {
#     seconds: 7
#     nanos: 882875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.452906638
#     top: 0.340700209
#     right: 0.586858392
#     bottom: 0.752946734
#   }
#   time_offset {
#     seconds: 8
#     nanos: 8000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.46485132
#     top: 0.363064736
#     right: 0.607239068
#     bottom: 0.787212491
#   }
#   time_offset {
#     seconds: 8
#     nanos: 133125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.469671637
#     top: 0.39033705
#     right: 0.616252065
#     bottom: 0.801100552
#   }
#   time_offset {
#     seconds: 8
#     nanos: 258250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.484370172
#     top: 0.506304145
#     right: 0.573811293
#     bottom: 0.754237056
#   }
#   time_offset {
#     seconds: 8
#     nanos: 383375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.477983057
#     top: 0.506346226
#     right: 0.567558289
#     bottom: 0.75448215
#   }
#   time_offset {
#     seconds: 8
#     nanos: 508500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.479685605
#     top: 0.502257109
#     right: 0.569268405
#     bottom: 0.750404477
#   }
#   time_offset {
#     seconds: 8
#     nanos: 633625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.476878762
#     top: 0.490316719
#     right: 0.570852458
#     bottom: 0.749738932
#   }
#   time_offset {
#     seconds: 8
#     nanos: 758750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.445059866
#     top: 0.352365047
#     right: 0.577128053
#     bottom: 0.78408289
#   }
#   time_offset {
#     seconds: 8
#     nanos: 883875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.438530326
#     top: 0.327970564
#     right: 0.570598483
#     bottom: 0.759688437
#   }
#   time_offset {
#     seconds: 9
#     nanos: 9000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.432000786
#     top: 0.303576082
#     right: 0.564069
#     bottom: 0.735294
#   }
#   time_offset {
#     seconds: 9
#     nanos: 134125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.390758574
#     top: 0.311807454
#     right: 0.619148195
#     bottom: 0.757831872
#   }
#   time_offset {
#     seconds: 9
#     nanos: 259250000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 7
#     nanos: 882875000
#   }
#   end_time_offset {
#     seconds: 8
#     nanos: 8000000
#   }
# }
# entity {
#   entity_id: "/m/03gx245"
#   description: "top"
#   language_code: "en-US"
# }
# confidence: 0.610797346
# frames {
#   normalized_bounding_box {
#     left: 0.455038935
#     top: 0.362562597
#     right: 0.566031396
#     bottom: 0.547648489
#   }
#   time_offset {
#     seconds: 7
#     nanos: 882875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.485178798
#     top: 0.581120729
#     right: 0.566998065
#     bottom: 0.781375468
#   }
#   time_offset {
#     seconds: 8
#     nanos: 8000000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 8
#     nanos: 258250000
#   }
#   end_time_offset {
#     seconds: 8
#     nanos: 258250000
#   }
# }
# entity {
#   entity_id: "/m/029zz6"
#   description: "display device"
#   language_code: "en-US"
# }
# confidence: 0.635767937
# frames {
#   normalized_bounding_box {
#     left: 0.339386344
#     right: 0.643012
#     bottom: 1
#   }
#   time_offset {
#     seconds: 8
#     nanos: 258250000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 8
#     nanos: 383375000
#   }
#   end_time_offset {
#     seconds: 9
#     nanos: 259250000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.953486681
# frames {
#   normalized_bounding_box {
#     left: 0.441263258
#     top: 0.282776475
#     right: 0.578708827
#     bottom: 0.769884
#   }
#   time_offset {
#     seconds: 8
#     nanos: 383375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.460908473
#     top: 0.334181488
#     right: 0.616089
#     bottom: 0.809200406
#   }
#   time_offset {
#     seconds: 8
#     nanos: 508500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.444590509
#     top: 0.267956465
#     right: 0.57697475
#     bottom: 0.761745214
#   }
#   time_offset {
#     seconds: 8
#     nanos: 633625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.442168087
#     top: 0.271355808
#     right: 0.572528601
#     bottom: 0.765754342
#   }
#   time_offset {
#     seconds: 8
#     nanos: 758750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.439871579
#     top: 0.267268211
#     right: 0.575907707
#     bottom: 0.784978509
#   }
#   time_offset {
#     seconds: 8
#     nanos: 883875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.412830025
#     top: 0.265428185
#     right: 0.597073376
#     bottom: 0.764400959
#   }
#   time_offset {
#     seconds: 9
#     nanos: 9000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.410086125
#     top: 0.262239397
#     right: 0.597363
#     bottom: 0.759581566
#   }
#   time_offset {
#     seconds: 9
#     nanos: 134125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.410647154
#     top: 0.262518436
#     right: 0.598131716
#     bottom: 0.759748936
#   }
#   time_offset {
#     seconds: 9
#     nanos: 259250000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 8
#     nanos: 508500000
#   }
#   end_time_offset {
#     seconds: 8
#     nanos: 633625000
#   }
# }
# entity {
#   entity_id: "/j/5qg9b8"
#   description: "packaged goods"
#   language_code: "en-US"
# }
# confidence: 0.515108824
# frames {
#   normalized_bounding_box {
#     left: 0.326292306
#     right: 0.662837386
#     bottom: 1
#   }
#   time_offset {
#     seconds: 8
#     nanos: 508500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.443325341
#     top: 0.124817573
#     right: 0.575559497
#     bottom: 0.253356755
#   }
#   time_offset {
#     seconds: 8
#     nanos: 633625000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 8
#     nanos: 758750000
#   }
#   end_time_offset {
#     seconds: 9
#     nanos: 134125000
#   }
# }
# entity {
#   entity_id: "/j/5qg9b8"
#   description: "packaged goods"
#   language_code: "en-US"
# }
# confidence: 0.582236052
# frames {
#   normalized_bounding_box {
#     left: 0.337982148
#     right: 0.652235866
#     bottom: 1
#   }
#   time_offset {
#     seconds: 8
#     nanos: 758750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.346085161
#     top: 0.00782343745
#     right: 0.648723364
#     bottom: 0.996688962
#   }
#   time_offset {
#     seconds: 8
#     nanos: 883875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.346350074
#     top: 0.0101300804
#     right: 0.648956597
#     bottom: 0.999017358
#   }
#   time_offset {
#     seconds: 9
#     nanos: 9000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.374670714
#     top: 0.0841155574
#     right: 0.645104468
#     bottom: 0.970632076
#   }
#   time_offset {
#     seconds: 9
#     nanos: 134125000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 9
#     nanos: 384375000
#   }
#   end_time_offset {
#     seconds: 12
#     nanos: 387375000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.953823805
# frames {
#   normalized_bounding_box {
#     left: 0.569890201
#     top: 0.311845928
#     right: 0.657501101
#     bottom: 0.626995623
#   }
#   time_offset {
#     seconds: 9
#     nanos: 384375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.567711592
#     top: 0.312036753
#     right: 0.655211747
#     bottom: 0.626852095
#   }
#   time_offset {
#     seconds: 9
#     nanos: 509500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.567705035
#     top: 0.312037081
#     right: 0.655205071
#     bottom: 0.626851916
#   }
#   time_offset {
#     seconds: 9
#     nanos: 634625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.561143875
#     top: 0.335724
#     right: 0.637812
#     bottom: 0.616274834
#   }
#   time_offset {
#     seconds: 9
#     nanos: 759750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.557755291
#     top: 0.34286356
#     right: 0.633352935
#     bottom: 0.620827
#   }
#   time_offset {
#     seconds: 9
#     nanos: 884875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.556243718
#     top: 0.340642154
#     right: 0.631769896
#     bottom: 0.61843276
#   }
#   time_offset {
#     seconds: 10
#     nanos: 10000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.556993365
#     top: 0.335953236
#     right: 0.634903908
#     bottom: 0.608147264
#   }
#   time_offset {
#     seconds: 10
#     nanos: 135125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.559361041
#     top: 0.334119469
#     right: 0.636986315
#     bottom: 0.605477571
#   }
#   time_offset {
#     seconds: 10
#     nanos: 260250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.562952816
#     top: 0.34162423
#     right: 0.637164891
#     bottom: 0.600858748
#   }
#   time_offset {
#     seconds: 10
#     nanos: 385375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.577816129
#     top: 0.343628168
#     right: 0.635800898
#     bottom: 0.609681666
#   }
#   time_offset {
#     seconds: 10
#     nanos: 510500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.581513762
#     top: 0.346116751
#     right: 0.638369262
#     bottom: 0.611879349
#   }
#   time_offset {
#     seconds: 10
#     nanos: 635625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.581738055
#     top: 0.347654521
#     right: 0.638514757
#     bottom: 0.613396764
#   }
#   time_offset {
#     seconds: 10
#     nanos: 760750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.580021799
#     top: 0.365915
#     right: 0.634757221
#     bottom: 0.603009641
#   }
#   time_offset {
#     seconds: 10
#     nanos: 885875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.57808286
#     top: 0.370203078
#     right: 0.632287621
#     bottom: 0.604652226
#   }
#   time_offset {
#     seconds: 11
#     nanos: 11000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.578106284
#     top: 0.377161235
#     right: 0.629851341
#     bottom: 0.601090312
#   }
#   time_offset {
#     seconds: 11
#     nanos: 136125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.577358425
#     top: 0.38098225
#     right: 0.625296652
#     bottom: 0.605872273
#   }
#   time_offset {
#     seconds: 11
#     nanos: 261250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.576255262
#     top: 0.385510057
#     right: 0.623688698
#     bottom: 0.609640718
#   }
#   time_offset {
#     seconds: 11
#     nanos: 386375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.576469
#     top: 0.388431817
#     right: 0.623867452
#     bottom: 0.612509847
#   }
#   time_offset {
#     seconds: 11
#     nanos: 511500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.574648559
#     top: 0.393265933
#     right: 0.635230124
#     bottom: 0.611805379
#   }
#   time_offset {
#     seconds: 11
#     nanos: 636625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.577331543
#     top: 0.390568465
#     right: 0.638729572
#     bottom: 0.60822618
#   }
#   time_offset {
#     seconds: 11
#     nanos: 761750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.5799945
#     top: 0.386731118
#     right: 0.641448677
#     bottom: 0.604328215
#   }
#   time_offset {
#     seconds: 11
#     nanos: 886875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.589523435
#     top: 0.367491335
#     right: 0.637507796
#     bottom: 0.607713819
#   }
#   time_offset {
#     seconds: 12
#     nanos: 12000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.591793776
#     top: 0.362179786
#     right: 0.638747513
#     bottom: 0.603744
#   }
#   time_offset {
#     seconds: 12
#     nanos: 137125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.593873441
#     top: 0.359667212
#     right: 0.640753865
#     bottom: 0.601326764
#   }
#   time_offset {
#     seconds: 12
#     nanos: 262250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.59615773
#     top: 0.357293218
#     right: 0.657960773
#     bottom: 0.596685827
#   }
#   time_offset {
#     seconds: 12
#     nanos: 387375000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 9
#     nanos: 384375000
#   }
#   end_time_offset {
#     seconds: 12
#     nanos: 387375000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.95862025
# frames {
#   normalized_bounding_box {
#     left: 0.273778468
#     top: 0.32740891
#     right: 0.388071567
#     bottom: 0.620769083
#   }
#   time_offset {
#     seconds: 9
#     nanos: 384375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.274998158
#     top: 0.328701735
#     right: 0.389061034
#     bottom: 0.621295512
#   }
#   time_offset {
#     seconds: 9
#     nanos: 509500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.27753967
#     top: 0.326900125
#     right: 0.391602188
#     bottom: 0.619492769
#   }
#   time_offset {
#     seconds: 9
#     nanos: 634625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.300318807
#     top: 0.329044908
#     right: 0.393954694
#     bottom: 0.604900241
#   }
#   time_offset {
#     seconds: 9
#     nanos: 759750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.306371689
#     top: 0.330548137
#     right: 0.398172468
#     bottom: 0.60474354
#   }
#   time_offset {
#     seconds: 9
#     nanos: 884875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.312116176
#     top: 0.332942665
#     right: 0.403792113
#     bottom: 0.607025146
#   }
#   time_offset {
#     seconds: 10
#     nanos: 10000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.330293357
#     top: 0.323316127
#     right: 0.417760462
#     bottom: 0.600016475
#   }
#   time_offset {
#     seconds: 10
#     nanos: 135125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.34212184
#     top: 0.321160078
#     right: 0.429134876
#     bottom: 0.59800142
#   }
#   time_offset {
#     seconds: 10
#     nanos: 260250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.349049121
#     top: 0.322891206
#     right: 0.436030626
#     bottom: 0.599742353
#   }
#   time_offset {
#     seconds: 10
#     nanos: 385375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.365853518
#     top: 0.346087813
#     right: 0.428908855
#     bottom: 0.604104817
#   }
#   time_offset {
#     seconds: 10
#     nanos: 510500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.367577553
#     top: 0.353275269
#     right: 0.428658813
#     bottom: 0.609860957
#   }
#   time_offset {
#     seconds: 10
#     nanos: 635625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.36737451
#     top: 0.355290145
#     right: 0.428321958
#     bottom: 0.611778855
#   }
#   time_offset {
#     seconds: 10
#     nanos: 760750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.373849452
#     top: 0.36460039
#     right: 0.422716677
#     bottom: 0.601785541
#   }
#   time_offset {
#     seconds: 10
#     nanos: 885875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.372833878
#     top: 0.358666211
#     right: 0.423242718
#     bottom: 0.605208755
#   }
#   time_offset {
#     seconds: 11
#     nanos: 11000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.37250942
#     top: 0.357492447
#     right: 0.423022419
#     bottom: 0.604667068
#   }
#   time_offset {
#     seconds: 11
#     nanos: 136125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.376300335
#     top: 0.373273551
#     right: 0.420518279
#     bottom: 0.59862411
#   }
#   time_offset {
#     seconds: 11
#     nanos: 261250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.376416653
#     top: 0.377283961
#     right: 0.419712484
#     bottom: 0.600580633
#   }
#   time_offset {
#     seconds: 11
#     nanos: 386375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.37557134
#     top: 0.378568262
#     right: 0.418805122
#     bottom: 0.601726651
#   }
#   time_offset {
#     seconds: 11
#     nanos: 511500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.374092937
#     top: 0.384511232
#     right: 0.415101826
#     bottom: 0.600958049
#   }
#   time_offset {
#     seconds: 11
#     nanos: 636625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.373231083
#     top: 0.384714752
#     right: 0.413882434
#     bottom: 0.600504
#   }
#   time_offset {
#     seconds: 11
#     nanos: 761750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.372573644
#     top: 0.383179605
#     right: 0.413200468
#     bottom: 0.598923683
#   }
#   time_offset {
#     seconds: 11
#     nanos: 886875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.370944828
#     top: 0.360278249
#     right: 0.419789106
#     bottom: 0.601809859
#   }
#   time_offset {
#     seconds: 12
#     nanos: 12000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.372281402
#     top: 0.353883922
#     right: 0.421231627
#     bottom: 0.596401
#   }
#   time_offset {
#     seconds: 12
#     nanos: 137125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.37304914
#     top: 0.35329324
#     right: 0.422006905
#     bottom: 0.595880628
#   }
#   time_offset {
#     seconds: 12
#     nanos: 262250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.366046786
#     top: 0.370878667
#     right: 0.417623192
#     bottom: 0.598629057
#   }
#   time_offset {
#     seconds: 12
#     nanos: 387375000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 9
#     nanos: 384375000
#   }
#   end_time_offset {
#     seconds: 12
#     nanos: 387375000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.959800899
# frames {
#   normalized_bounding_box {
#     left: 0.645367205
#     top: 0.358643711
#     right: 0.705940545
#     bottom: 0.607452095
#   }
#   time_offset {
#     seconds: 9
#     nanos: 384375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.642712355
#     top: 0.357409269
#     right: 0.703129292
#     bottom: 0.605558455
#   }
#   time_offset {
#     seconds: 9
#     nanos: 509500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.639151037
#     top: 0.352892935
#     right: 0.699567735
#     bottom: 0.601041138
#   }
#   time_offset {
#     seconds: 9
#     nanos: 634625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.635338902
#     top: 0.353442669
#     right: 0.684959292
#     bottom: 0.605480731
#   }
#   time_offset {
#     seconds: 9
#     nanos: 759750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.631734431
#     top: 0.351519883
#     right: 0.682677269
#     bottom: 0.615446448
#   }
#   time_offset {
#     seconds: 9
#     nanos: 884875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.631574035
#     top: 0.359480202
#     right: 0.680187047
#     bottom: 0.612177968
#   }
#   time_offset {
#     seconds: 10
#     nanos: 10000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.628261924
#     top: 0.33936125
#     right: 0.693298817
#     bottom: 0.607628763
#   }
#   time_offset {
#     seconds: 10
#     nanos: 135125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.629946947
#     top: 0.335087568
#     right: 0.696014822
#     bottom: 0.603588462
#   }
#   time_offset {
#     seconds: 10
#     nanos: 260250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.632009685
#     top: 0.341722757
#     right: 0.695241451
#     bottom: 0.598174393
#   }
#   time_offset {
#     seconds: 10
#     nanos: 385375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.638809502
#     top: 0.343514174
#     right: 0.689108729
#     bottom: 0.604297161
#   }
#   time_offset {
#     seconds: 10
#     nanos: 510500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.638175905
#     top: 0.342752546
#     right: 0.687227547
#     bottom: 0.602979302
#   }
#   time_offset {
#     seconds: 10
#     nanos: 635625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.635471582
#     top: 0.34375006
#     right: 0.684436381
#     bottom: 0.603938103
#   }
#   time_offset {
#     seconds: 10
#     nanos: 760750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.633973539
#     top: 0.37960124
#     right: 0.674316585
#     bottom: 0.587913
#   }
#   time_offset {
#     seconds: 10
#     nanos: 885875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.631518424
#     top: 0.389410257
#     right: 0.671150804
#     bottom: 0.593411326
#   }
#   time_offset {
#     seconds: 11
#     nanos: 11000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.628225386
#     top: 0.393035203
#     right: 0.667812109
#     bottom: 0.596759439
#   }
#   time_offset {
#     seconds: 11
#     nanos: 136125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.625053346
#     top: 0.393961877
#     right: 0.663766
#     bottom: 0.598656297
#   }
#   time_offset {
#     seconds: 11
#     nanos: 261250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.623416662
#     top: 0.396109819
#     right: 0.661970198
#     bottom: 0.600743949
#   }
#   time_offset {
#     seconds: 11
#     nanos: 386375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.623047948
#     top: 0.396728933
#     right: 0.661590457
#     bottom: 0.601358891
#   }
#   time_offset {
#     seconds: 11
#     nanos: 511500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.618562579
#     top: 0.398985684
#     right: 0.6680969
#     bottom: 0.59889251
#   }
#   time_offset {
#     seconds: 11
#     nanos: 636625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.620793343
#     top: 0.402681679
#     right: 0.668336272
#     bottom: 0.593190789
#   }
#   time_offset {
#     seconds: 11
#     nanos: 761750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.62261641
#     top: 0.401098847
#     right: 0.670022309
#     bottom: 0.590961099
#   }
#   time_offset {
#     seconds: 11
#     nanos: 886875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.630749583
#     top: 0.390300333
#     right: 0.672195
#     bottom: 0.592946231
#   }
#   time_offset {
#     seconds: 12
#     nanos: 12000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.634499073
#     top: 0.387895703
#     right: 0.675181806
#     bottom: 0.590664208
#   }
#   time_offset {
#     seconds: 12
#     nanos: 137125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.637546062
#     top: 0.388651818
#     right: 0.678175032
#     bottom: 0.591428936
#   }
#   time_offset {
#     seconds: 12
#     nanos: 262250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.647023141
#     top: 0.402256459
#     right: 0.690456808
#     bottom: 0.592978597
#   }
#   time_offset {
#     seconds: 12
#     nanos: 387375000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 9
#     nanos: 384375000
#   }
#   end_time_offset {
#     seconds: 12
#     nanos: 387375000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.914105415
# frames {
#   normalized_bounding_box {
#     left: 0.399434805
#     top: 0.340375274
#     right: 0.465470701
#     bottom: 0.599902332
#   }
#   time_offset {
#     seconds: 9
#     nanos: 384375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.399999142
#     top: 0.339815646
#     right: 0.465624779
#     bottom: 0.599075317
#   }
#   time_offset {
#     seconds: 9
#     nanos: 509500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.401015639
#     top: 0.339813769
#     right: 0.466640681
#     bottom: 0.599073052
#   }
#   time_offset {
#     seconds: 9
#     nanos: 634625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.421032161
#     top: 0.353226125
#     right: 0.464282
#     bottom: 0.592803657
#   }
#   time_offset {
#     seconds: 9
#     nanos: 759750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.425260276
#     top: 0.357057154
#     right: 0.466548562
#     bottom: 0.59512943
#   }
#   time_offset {
#     seconds: 9
#     nanos: 884875000
# ...
#     bottom: 0.6503703
#   }
#   time_offset {
#     seconds: 19
#     nanos: 644625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.188008204
#     top: 0.461048365
#     right: 0.287994146
#     bottom: 0.652687252
#   }
#   time_offset {
#     seconds: 19
#     nanos: 769750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.183211401
#     top: 0.475597739
#     right: 0.27713865
#     bottom: 0.649743259
#   }
#   time_offset {
#     seconds: 19
#     nanos: 894875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.178380519
#     top: 0.487034321
#     right: 0.27758956
#     bottom: 0.651259482
#   }
#   time_offset {
#     seconds: 20
#     nanos: 20000000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 19
#     nanos: 519500000
#   }
#   end_time_offset {
#     seconds: 19
#     nanos: 644625000
#   }
# }
# entity {
#   entity_id: "/m/01rkbr"
#   description: "tie"
#   language_code: "en-US"
# }
# confidence: 0.538717926
# frames {
#   normalized_bounding_box {
#     left: 0.318716407
#     top: 0.251709104
#     right: 0.405550122
#     bottom: 0.462195337
#   }
#   time_offset {
#     seconds: 19
#     nanos: 519500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.61759305
#     top: 0.258917272
#     right: 0.662804186
#     bottom: 0.499587774
#   }
#   time_offset {
#     seconds: 19
#     nanos: 644625000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 20
#     nanos: 895875000
#   }
#   end_time_offset {
#     seconds: 20
#     nanos: 895875000
#   }
# }
# entity {
#   entity_id: "/m/01b7fy"
#   description: "headphones"
#   language_code: "en-US"
# }
# confidence: 0.847988963
# frames {
#   normalized_bounding_box {
#     left: 0.425724149
#     top: 0.198588982
#     right: 0.593841314
#     bottom: 0.604082584
#   }
#   time_offset {
#     seconds: 20
#     nanos: 895875000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 22
#     nanos: 147125000
#   }
#   end_time_offset {
#     seconds: 24
#     nanos: 649625000
#   }
# }
# entity {
#   entity_id: "/m/01g317"
#   description: "person"
#   language_code: "en-US"
# }
# confidence: 0.927925348
# frames {
#   normalized_bounding_box {
#     left: 0.444879681
#     top: 0.514447093
#     right: 0.551497221
#     bottom: 0.999118865
#   }
#   time_offset {
#     seconds: 22
#     nanos: 147125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.444271713
#     top: 0.321586668
#     right: 0.550522268
#     bottom: 0.805846572
#   }
#   time_offset {
#     seconds: 22
#     nanos: 272250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.444269627
#     top: 0.267774791
#     right: 0.550519645
#     bottom: 0.752034068
#   }
#   time_offset {
#     seconds: 22
#     nanos: 397375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.441560358
#     top: 0.24356097
#     right: 0.549911678
#     bottom: 0.858794749
#   }
#   time_offset {
#     seconds: 22
#     nanos: 522500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.441227645
#     top: 0.25309214
#     right: 0.549562275
#     bottom: 0.876520276
#   }
#   time_offset {
#     seconds: 22
#     nanos: 647625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.441238791
#     top: 0.260366857
#     right: 0.549572229
#     bottom: 0.884396136
#   }
#   time_offset {
#     seconds: 22
#     nanos: 772750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.440403819
#     top: 0.266401559
#     right: 0.548737168
#     bottom: 0.890472531
#   }
#   time_offset {
#     seconds: 22
#     nanos: 897875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.439679474
#     top: 0.269479901
#     right: 0.548012793
#     bottom: 0.893553734
#   }
#   time_offset {
#     seconds: 23
#     nanos: 23000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.439685643
#     top: 0.268788338
#     right: 0.548019
#     bottom: 0.892862439
#   }
#   time_offset {
#     seconds: 23
#     nanos: 148125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.442525983
#     top: 0.276409596
#     right: 0.554963052
#     bottom: 0.868846774
#   }
#   time_offset {
#     seconds: 23
#     nanos: 273250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.444365621
#     top: 0.272727787
#     right: 0.556861341
#     bottom: 0.862721562
#   }
#   time_offset {
#     seconds: 23
#     nanos: 398375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.445053399
#     top: 0.271127641
#     right: 0.557553113
#     bottom: 0.860954881
#   }
#   time_offset {
#     seconds: 23
#     nanos: 523500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.443423182
#     top: 0.261267126
#     right: 0.554211259
#     bottom: 0.849652
#   }
#   time_offset {
#     seconds: 23
#     nanos: 648625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.441626161
#     top: 0.257116
#     right: 0.552068532
#     bottom: 0.845108151
#   }
#   time_offset {
#     seconds: 23
#     nanos: 773750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.43868348
#     top: 0.255768955
#     right: 0.549101949
#     bottom: 0.843733966
#   }
#   time_offset {
#     seconds: 23
#     nanos: 898875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.427073896
#     top: 0.253438145
#     right: 0.550768
#     bottom: 0.871706605
#   }
#   time_offset {
#     seconds: 24
#     nanos: 24000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.424349934
#     top: 0.260795087
#     right: 0.548774
#     bottom: 0.881018043
#   }
#   time_offset {
#     seconds: 24
#     nanos: 149125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.423585087
#     top: 0.263318717
#     right: 0.548060417
#     bottom: 0.883678913
#   }
#   time_offset {
#     seconds: 24
#     nanos: 274250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.421682954
#     top: 0.267718762
#     right: 0.546158314
#     bottom: 0.888078928
#   }
#   time_offset {
#     seconds: 24
#     nanos: 399375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.419780821
#     top: 0.272118807
#     right: 0.544256151
#     bottom: 0.892479
#   }
#   time_offset {
#     seconds: 24
#     nanos: 524500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.426582545
#     top: 0.26847738
#     right: 0.549100578
#     bottom: 0.844237268
#   }
#   time_offset {
#     seconds: 24
#     nanos: 649625000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 22
#     nanos: 147125000
#   }
#   end_time_offset {
#     seconds: 22
#     nanos: 147125000
#   }
# }
# entity {
#   entity_id: "/m/054_l"
#   description: "mirror"
#   language_code: "en-US"
# }
# confidence: 0.670167148
# frames {
#   normalized_bounding_box {
#     left: 0.349892318
#     top: 0.288856924
#     right: 0.640321076
#     bottom: 0.990934253
#   }
#   time_offset {
#     seconds: 22
#     nanos: 147125000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 22
#     nanos: 397375000
#   }
#   end_time_offset {
#     seconds: 24
#     nanos: 899875000
#   }
# }
# entity {
#   entity_id: "/m/0jbk"
#   description: "animal"
#   language_code: "en-US"
# }
# confidence: 0.688099504
# frames {
#   normalized_bounding_box {
#     left: 0.429531783
#     top: 0.282023549
#     right: 0.55793941
#     bottom: 0.860749841
#   }
#   time_offset {
#     seconds: 22
#     nanos: 397375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.429531783
#     top: 0.282023549
#     right: 0.55793941
#     bottom: 0.860749841
#   }
#   time_offset {
#     seconds: 22
#     nanos: 522500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.429531783
#     top: 0.282023549
#     right: 0.55793941
#     bottom: 0.860749841
#   }
#   time_offset {
#     seconds: 22
#     nanos: 647625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.429531783
#     top: 0.282023549
#     right: 0.55793941
#     bottom: 0.860749841
#   }
#   time_offset {
#     seconds: 22
#     nanos: 772750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.430728316
#     top: 0.270379633
#     right: 0.559373796
#     bottom: 0.849083424
#   }
#   time_offset {
#     seconds: 22
#     nanos: 897875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.432229102
#     top: 0.264998227
#     right: 0.560874939
#     bottom: 0.843701959
#   }
#   time_offset {
#     seconds: 23
#     nanos: 23000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.434679389
#     top: 0.260884166
#     right: 0.563325226
#     bottom: 0.839587867
#   }
#   time_offset {
#     seconds: 23
#     nanos: 148125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.436733812
#     top: 0.256355047
#     right: 0.56537962
#     bottom: 0.835058749
#   }
#   time_offset {
#     seconds: 23
#     nanos: 273250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.431189388
#     top: 0.275677502
#     right: 0.561626256
#     bottom: 0.858516932
#   }
#   time_offset {
#     seconds: 23
#     nanos: 398375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.427195519
#     top: 0.265046686
#     right: 0.560335279
#     bottom: 0.873669744
#   }
#   time_offset {
#     seconds: 23
#     nanos: 523500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.425901383
#     top: 0.26891309
#     right: 0.559041142
#     bottom: 0.877536178
#   }
#   time_offset {
#     seconds: 23
#     nanos: 648625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.424607247
#     top: 0.272779495
#     right: 0.557747
#     bottom: 0.881402612
#   }
#   time_offset {
#     seconds: 23
#     nanos: 773750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.423313111
#     top: 0.276645899
#     right: 0.55645287
#     bottom: 0.885269
#   }
#   time_offset {
#     seconds: 23
#     nanos: 898875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.420750856
#     top: 0.247986495
#     right: 0.540648103
#     bottom: 0.870908082
#   }
#   time_offset {
#     seconds: 24
#     nanos: 24000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.417393863
#     top: 0.245217592
#     right: 0.53729111
#     bottom: 0.868139148
#   }
#   time_offset {
#     seconds: 24
#     nanos: 149125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.41403687
#     top: 0.242448673
#     right: 0.533934116
#     bottom: 0.865370274
#   }
#   time_offset {
#     seconds: 24
#     nanos: 274250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.419484675
#     top: 0.254300952
#     right: 0.544830441
#     bottom: 0.853826165
#   }
#   time_offset {
#     seconds: 24
#     nanos: 399375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.423726439
#     top: 0.253391385
#     right: 0.540299714
#     bottom: 0.853140652
#   }
#   time_offset {
#     seconds: 24
#     nanos: 524500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.423736632
#     top: 0.25193128
#     right: 0.540309906
#     bottom: 0.851680517
#   }
#   time_offset {
#     seconds: 24
#     nanos: 649625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.424317807
#     top: 0.250809133
#     right: 0.540981
#     bottom: 0.850799859
#   }
#   time_offset {
#     seconds: 24
#     nanos: 774750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.417734712
#     top: 0.248376638
#     right: 0.552491248
#     bottom: 0.842134595
#   }
#   time_offset {
#     seconds: 24
#     nanos: 899875000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 22
#     nanos: 772750000
#   }
#   end_time_offset {
#     seconds: 24
#     nanos: 274250000
#   }
# }
# entity {
#   entity_id: "/m/07mhn"
#   description: "pants"
#   language_code: "en-US"
# }
# confidence: 0.674521267
# frames {
#   normalized_bounding_box {
#     left: 0.460979968
#     top: 0.610803246
#     right: 0.55182761
#     bottom: 0.866795897
#   }
#   time_offset {
#     seconds: 22
#     nanos: 772750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.46093756
#     top: 0.612959683
#     right: 0.551562905
#     bottom: 0.868515968
#   }
#   time_offset {
#     seconds: 22
#     nanos: 897875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.459922165
#     top: 0.611161172
#     right: 0.550547183
#     bottom: 0.866716802
#   }
#   time_offset {
#     seconds: 23
#     nanos: 23000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.459300131
#     top: 0.609285414
#     right: 0.549925148
#     bottom: 0.864841
#   }
#   time_offset {
#     seconds: 23
#     nanos: 148125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.462126762
#     top: 0.609414577
#     right: 0.55275178
#     bottom: 0.864970148
#   }
#   time_offset {
#     seconds: 23
#     nanos: 273250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.462710381
#     top: 0.6108163
#     right: 0.553335369
#     bottom: 0.86637187
#   }
#   time_offset {
#     seconds: 23
#     nanos: 398375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.461912
#     top: 0.609327
#     right: 0.552537
#     bottom: 0.864882588
#   }
#   time_offset {
#     seconds: 23
#     nanos: 523500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.457527608
#     top: 0.610191047
#     right: 0.548152626
#     bottom: 0.865746617
#   }
#   time_offset {
#     seconds: 23
#     nanos: 648625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.44999516
#     top: 0.613504171
#     right: 0.543071091
#     bottom: 0.858758748
#   }
#   time_offset {
#     seconds: 23
#     nanos: 773750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.446559817
#     top: 0.614603102
#     right: 0.539778471
#     bottom: 0.859965563
#   }
#   time_offset {
#     seconds: 23
#     nanos: 898875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.438280642
#     top: 0.619332671
#     right: 0.531509101
#     bottom: 0.864702463
#   }
#   time_offset {
#     seconds: 24
#     nanos: 24000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.433979124
#     top: 0.618546784
#     right: 0.527208209
#     bottom: 0.863917112
#   }
#   time_offset {
#     seconds: 24
#     nanos: 149125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.439668149
#     top: 0.618804038
#     right: 0.528812468
#     bottom: 0.866106272
#   }
#   time_offset {
#     seconds: 24
#     nanos: 274250000
#   }
# }
# , segment {
#   start_time_offset {
#     seconds: 23
#     nanos: 273250000
#   }
#   end_time_offset {
#     seconds: 24
#     nanos: 774750000
#   }
# }
# entity {
#   entity_id: "/m/03gx245"
#   description: "top"
#   language_code: "en-US"
# }
# confidence: 0.582100093
# frames {
#   normalized_bounding_box {
#     left: 0.440610826
#     top: 0.401733965
#     right: 0.546868742
#     bottom: 0.62973839
#   }
#   time_offset {
#     seconds: 23
#     nanos: 273250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.437504679
#     top: 0.404625267
#     right: 0.543754697
#     bottom: 0.632403374
#   }
#   time_offset {
#     seconds: 23
#     nanos: 398375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.436987907
#     top: 0.402829081
#     right: 0.543237925
#     bottom: 0.63060689
#   }
#   time_offset {
#     seconds: 23
#     nanos: 523500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.438624471
#     top: 0.404797316
#     right: 0.544874489
#     bottom: 0.632575095
#   }
#   time_offset {
#     seconds: 23
#     nanos: 648625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.43702212
#     top: 0.39273718
#     right: 0.542985141
#     bottom: 0.634938717
#   }
#   time_offset {
#     seconds: 23
#     nanos: 773750000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.434599727
#     top: 0.394109219
#     right: 0.540345311
#     bottom: 0.636674285
#   }
#   time_offset {
#     seconds: 23
#     nanos: 898875000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.432654351
#     top: 0.393008232
#     right: 0.538384676
#     bottom: 0.635598898
#   }
#   time_offset {
#     seconds: 24
#     nanos: 24000000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.432109892
#     top: 0.392470419
#     right: 0.537839174
#     bottom: 0.635062873
#   }
#   time_offset {
#     seconds: 24
#     nanos: 149125000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.431138486
#     top: 0.391167045
#     right: 0.536867678
#     bottom: 0.633759618
#   }
#   time_offset {
#     seconds: 24
#     nanos: 274250000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.430155098
#     top: 0.391666979
#     right: 0.535884261
#     bottom: 0.634259582
#   }
#   time_offset {
#     seconds: 24
#     nanos: 399375000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.430102736
#     top: 0.388734102
#     right: 0.535831928
#     bottom: 0.631326675
#   }
#   time_offset {
#     seconds: 24
#     nanos: 524500000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.438547701
#     top: 0.383489668
#     right: 0.529654324
#     bottom: 0.636890292
#   }
#   time_offset {
#     seconds: 24
#     nanos: 649625000
#   }
# }
# frames {
#   normalized_bounding_box {
#     left: 0.43453452
#     top: 0.395487607
#     right: 0.529459357
#     bottom: 0.632848442
#   }
#   time_offset {
#     seconds: 24
#     nanos: 774750000
#   }
# }
# ]
